# %% [markdown]
# <a href="https://colab.research.google.com/github/lojain-IT/database-sql/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=2
b=3.4
print(a+b)


name=input('Enter your name: ')
print('welcome'+name)


number=int(input('enter your grade:'))
if number>50:
  print('pass')
else:
  print('fail')


  arr=[1,2,3,4,5]
  print(arr[0])
  print(arr[4])

for i in (1,11):
  if i==5:
    continue
  print(i)


student={
    'name':'lojain',
    'age':20,
    'grade':100
}

print(student['grade'])




def square(num):
 return num**2


print(square(4))




def bigger(a,b):
  if a>b:
   print(a)
  else:
    print(b)

print(bigger(2,9))


file=open('data.txt','w')
file.write('Hello python')
file.close()


file=open('data.txt','r')
content=file.read()
file.close()
print(content)
# Out:
#   File "/tmp/ipython-input-985700616.py", line 63
#     arr=[1,2,3,4,5]
#     ^
# IndentationError: unexpected indent
